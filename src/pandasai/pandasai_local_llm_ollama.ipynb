# %%
import pandas as pd

df = pd.read_csv('../data/census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %% [markdown]
# ### Local LLM

# %%
from pandasai.llm.local_llm import LocalLLM
from pandasai import SmartDataframe

ollama_llm = LocalLLM(api_base="http://localhost:11434/v1", model="codellama")


df = SmartDataframe(df, config={"llm": ollama_llm, "custom_whitelisted_dependencies": ["pandasai"]})

response = df.chat("What are the ctyname for state Alabama?")
# Out:
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 307, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\chat\code_generator.py", line 33, in execute
# ...

# %%
# from langchain_community.llms import Ollama
# from pandasai import SmartDataframe


# llm = Ollama(model="mistral")
# df = SmartDataframe(df, config={"llm": llm, "custom_whitelisted_dependencies": ["pandasai"], "verbose":True})
# df.chat("What are the ctyname for state Alabama?")
