# %%
import os
import pandas as pd
from pandasai import SmartDataframe
from pandasai.llm import GooglePalm
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

llm = GooglePalm(api_key=GOOGLE_API_KEY)

# %%
PANDASAI_API_KEY = os.getenv('PANDASAI_API_KEY')
os.environ["PANDASAI_API_KEY"] = PANDASAI_API_KEY

# %%
csv_path = os.path.join('..','data','census.csv')
df = pd.read_csv(csv_path)
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
smart_df = SmartDataframe(df, config={"llm": llm})

# %%
smart_df.chat('What are the top 5 REGION ?')
# Out:
#    REGION
# 3    1439
# 2    1067
# 4     461
# 1     226

# %%
# pip install pandasai google-generativeai

import os
import pandas as pd
from pandasai import SmartDataframe
from pandasai.llm import GooglePalm
from dotenv import load_dotenv
load_dotenv()

def get_response_from_pandasai():

    # Google Palm LLM
    GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    llm = GooglePalm(api_key=GOOGLE_API_KEY)

    # Pandasai API
    PANDASAI_API_KEY = os.getenv('PANDASAI_API_KEY')
    os.environ["PANDASAI_API_KEY"] = PANDASAI_API_KEY

    # load csv file as pandas dataframe
    csv_path = os.path.join('..','data','census.csv')
    df = pd.read_csv(csv_path)
    df.head()

    # create a smart dataframe
    smart_df = SmartDataframe(df, config={"llm": llm})

    # response = smart_df.chat('How many distinct number of values in the state column are present in the dataset?') # 51
    # response = smart_df.chat('How many distinct number of values in the ctyname column are present in the dataset?') # 1927
    # response = smart_df.chat('How many number of rows are present in the dataset?') #
    response = smart_df.chat('can you provide the middle row values of the dataset?') #
    print(response)

    

get_response_from_pandasai()
# Out:
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 307, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\sagar\work\AI_ML\gitrepo\GENAI\YOUTUBES\GenAI_research\venv\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
# ...
